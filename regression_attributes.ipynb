# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn import model_selection
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from xgboost import XGBRegressor
import xgboost as xgb
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
import math
from sklearn.metrics import f1_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics
df = pd.read_csv('speed_dating_data.csv', encoding = "ISO-8859-1")

# %% [markdown]
# ## ATTRACTIVENESS

# %%
data_1 = df[['pid','attr','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
attr = np.asarray(x['attr']).reshape(np.shape(x['attr'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,attr)
print(reg.score(dec,attr))
plot1 = sns.regplot(x=x['dec'], y=x['attr'],marker="+")
# Out:
# 0.6374866001378601

# %% [markdown]
# ## SINCERITY

# %%
data_1 = df[['pid','sinc','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
sinc = np.asarray(x['sinc']).reshape(np.shape(x['sinc'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,sinc)
print(reg.score(dec,sinc))
plot1 = sns.regplot(x=x['dec'], y=x['sinc'],marker="+")
# Out:
# 0.06296995821949547

# %% [markdown]
# ## FUN

# %%
data_1 = df[['pid','fun','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
fun = np.asarray(x['fun']).reshape(np.shape(x['fun'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,fun)
print(reg.score(dec,fun))
plot1 = sns.regplot(x=x['dec'], y=x['fun'],marker="+")
# Out:
# 0.43045166486230524

# %% [markdown]
# ## AMBITION

# %%
data_1 = df[['pid','amb','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
amb = np.asarray(x['amb']).reshape(np.shape(x['amb'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,amb)
print(reg.score(dec,amb))
plot1 = sns.regplot(x=x['dec'], y=x['amb'],marker="+")
# Out:
# 0.08062082742306276

# %% [markdown]
# ## SHARED INTERESTS

# %%
data_1 = df[['pid','shar','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
shar = np.asarray(x['shar']).reshape(np.shape(x['shar'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,shar)
print(reg.score(dec,shar))
plot1 = sns.regplot(x=x['dec'], y=x['shar'],marker="+")
# Out:
# 0.3714822513007586

# %% [markdown]
# ## INTELLIGENCE

# %%
data_1 = df[['pid','intel','dec','gender']].dropna()
x = data_1.groupby(['pid']).mean()
intel = np.asarray(x['intel']).reshape(np.shape(x['intel'])[0],1)
dec = np.asarray(x['dec']).reshape(np.shape(x['dec'])[0],1)
reg = LinearRegression().fit(dec,intel)
print(reg.score(dec,intel))
plot1 = sns.regplot(x=x['dec'], y=x['intel'],marker="+")
# Out:
# 0.07085363653444299
